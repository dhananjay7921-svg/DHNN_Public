# %% [markdown]
# <a href="https://colab.research.google.com/github/dhananjay7921-svg/DHNN_Public/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("Enter a number: "))
y=int(input("Enter another number: "))
def multiply(x,y):
  z=x*y
  return z

result = multiply(x,y)
print("The result of multiplication is",result,)
# Out:
# Enter a number: 12
# Enter another number: 12
# The result of multiplication is 144

# %%
effectve_return = lambda interest_rate, years: (1 + interest_rate) ** years
z=effectve_return(10,2)
print(z)
# Out:
# 121

# %%
import simfin as sf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3655332916.py in <cell line: 0>()
# ----> 1 import simfin as sf
#
# ModuleNotFoundError: No module named 'simfin'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install simfin
import simfin as sf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

# %%
import simfin as sf

# %%
import pandas as pd

# %%
sf.set_api_key('1bcb7900-4a31-4870-bb83-11d3dee7de09')

# %%
sf.set_data_dir('~/simfin_data/')

# %%
from numpy._core.fromnumeric import var
income_df=df.load_income(variant= 'quaterly',market='us')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1766497108.py in <cell line: 0>()
#       1 from numpy._core.fromnumeric import var
# ----> 2 income_df=df.load_income(variant= 'quaterly',market='us')
#
# NameError: name 'df' is not defined
