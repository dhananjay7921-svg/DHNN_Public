# %% [markdown]
# <a href="https://colab.research.google.com/github/dhananjay7921-svg/DHNN_Public/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simfin

# %%
import warnings

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import simfin as sf

# %%
import pandas as pd

# %%
sf.set_api_key('1bcb7900-4a31-4870-bb83-11d3dee7de09')

# %%
sf.set_data_dir('~/simfin_data/')

# %%
income_df=sf.load_income(variant='annual', market='us')
income_df

# %%
balance_df = sf.load_balance(variant = 'quarterly', market = 'us').reset_index()
balance_df

# %%
income_df.info()

# %%
cashflow_df = sf.load_cashflow(variant = 'quarterly', market = 'us').reset_index()
cashflow_df
cashflow_df.info()
# Out:
# Dataset "us-cashflow-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52355 entries, 0 to 52354
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Ticker                                     52355 non-null  object
#  1   Report Date                                52355 non-null  datetime64[ns]
#  2   SimFinId                                   52355 non-null  int64
#  3   Currency                                   52355 non-null  object
#  4   Fiscal Year                                52355 non-null  int64
#  5   Fiscal Period                              52355 non-null  object
#  6   Publish Date                               52355 non-null  datetime64[ns]
#  7   Restated Date                              52355 non-null  datetime64[ns]
# ...
